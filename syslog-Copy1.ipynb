# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
def genSyslogEntry(lines):

    etr ={} 
    etr[parm[0]] = lines[:15] #stime
    etr[parm[1]] = lines[15:].split()[0]

    ori = lines[15:].split()

    for i in range(1,len(ori)):  
        ori[i] = ori[i].replace("'",'"')
        #print(ori[i])
        if '=' in ori[i] != -1:
            if ori[i].find('"') != -1:
                ori[i] = ori[i].replace('"','')
                k = 1

                #while True and not (ori[i].split('=')[1]=='NA') and k < 10 and i<len(ori)-1 and ori[i].find('=') == -1:
                #print(ori[i]+' i '+str(i)+' len '+ str(len(ori))+' =? '+str(ori[i].find('=')))
                
                while (k < 10) and (i<len(ori)-1) and (ori[i+k].find('=') == -1):
                   # print(ori[i+k])
                    ori[i+k] = ori[i+k].replace("'",'"')
                    ori[i] = ori[i]+' '+ori[i+k]
                    if ori[i].find('"')!=-1:
                        ori[i] = ori[i].replace('"','')
                        break
                    k = k+1
            try:
                #print(ori[i])
                j = parm.index(ori[i].split('=')[0])
                etr[ori[i].split('=')[0]] = ori[i].split('=')[1]
            except:
                print(str(i)+' parámetro no encontrado  '+ori[i].split('=')[0])
            
    return etr

# %%
parm = 'stime ip id sn time fw pri c gcat m msg srcMac src srcZone natSrc dstMac dst dstZone natDst proto sent rcvd spkt rpkt cdur rule app n fw_action dpi appName sid appcat appid catid dstname Category arg code change note uuid op'.split()

# %%
log = open('data/10.4.45.log','r')
lines = log.readlines()

# %%
eetr = {}
metr = []

i = 0
for line in lines:
    #print(i)
    metr.append(genSyslogEntry(line))
    i = i+1
# Out:
# 26 parámetro no encontrado  ?ver
# 26 parámetro no encontrado  ?ver
# 26 parámetro no encontrado  ?ver
# 26 parámetro no encontrado  ?ver
# 26 parámetro no encontrado  ?ver

# %%
metr = []
metr.append(genSyslogEntry(lines[26]))

# %%
lines[26]
# Out:
# 'Aug 13 06:50:09 212.81.213.2   id=firewall sn=2CB8ED2DDA00 time="2020-08-13 06:50:09 UTC" fw=212.81.213.2 pri=1 c=0 gcat=10 m=1154 srcMac=d8:b1:22:ed:92:f7 src=10.4.45.73:43126:X2 srcZone=Trusted dstMac=2c:b8:ed:2d:da:02 dst=172.217.16.227:80:X1 dstZone=Untrusted proto=tcp/http rcvd=279 app=49175 appName=\'General HTTP\' msg="Application Control Detection Alert: PROTOCOLS HTTP Protocol -- GET, SID: 5147, AppID: 1277, CatID: 74" msg="Application Control Detection Alert: PROTOCOLS HTTP Protocol -- GET" sid=5147 appcat="PROTOCOLS HTTP Protocol -- GET" appid=1277 catid=74 n=577289 fw_action="NA"\n'

# %%
log.close()

# %%
df = pd.DataFrame(metr,columns=parm)
df
# Out:
#              stime            ip        id            sn  \
# 0  Aug 13 06:50:09  212.81.213.2  firewall  2CB8ED2DDA00
#
#                       time            fw pri  c gcat     m  ... appid catid  \
# 0  2020-08-13 06:50:09 UTC  212.81.213.2   1  0   10  1154  ...  1277    74
#
#   dstname Category  arg code change note  uuid  op
# 0     NaN      NaN  NaN  NaN    NaN  NaN   NaN NaN
#
# [1 rows x 43 columns]

# %%
# descomponemos la src Ip para tener sus partes: IP, port e if.
df['srcip'] = df['src'].apply(lambda x: x.split(':')[0])
df['srcport'] = df['src'].apply(lambda x: x.split(':')[1])
df['srcif'] = df['src'].apply(lambda x: x.split(':')[2])

# %%
srcip = df.groupby('srcip')

# %%
srcip.describe()['c']
# Out:
#                  count unique   top  freq
# srcip
# 10.0.28.73           6      1  1024     6
# 10.0.29.153          1      1  1024     1
# 10.4.45.189      10921      4  1024  4825
# 10.4.45.73        4291      4  1024  1779
# 10.4.46.109          4      1  1024     4
# 104.16.65.50        21      1     0    21
# 104.16.66.50        15      1     0    15
# 104.244.42.129       1      1     0     1
# 104.244.42.131       4      1     0     4
# 104.244.42.194       3      1     0     3
# 104.244.42.2         2      1     0     2
# 104.244.42.66        3      1     0     3
# 108.129.35.137       8      1     0     8
# 13.107.42.14       111      1     0   111
# 13.107.42.23         1      1     0     1
# 13.224.117.242       1      1     0     1
# 13.224.119.119       1      1     0     1
# 13.224.119.84        1      1     0     1
# 151.101.130.110      5      1     0     5
# 151.101.134.133      2      1     0     2
# 151.101.134.2        1      1     0     1
# 151.101.134.202      1      1     0     1
# 151.101.134.249      2      1     0     2
# 151.101.194.110      8      1     0     8
# 151.101.2.110       11      1     0    11
# 151.101.66.110      19      1     0    19
# 157.240.0.61         1      1     0     1
# 157.240.221.18       2      1     0     2
# 157.240.221.63       2      1     0     2
# 162.159.24.4         1      1     0     1
# ...                ...    ...   ...   ...
# 54.154.94.231        2      1     0     2
# 54.171.231.12        1      1     0     1
# 54.72.249.200        1      1     0     1
# 54.73.2.69           1      1     0     1
# 63.32.200.88         3      1     0     3
# 63.33.187.69         9      1     0     9
# 64.233.166.108       1      1     0     1
# 64.233.166.109       1      1     0     1
# 64.233.166.188       1      1     0     1
# 64.233.167.108       3      1     0     3
# 64.233.167.109       3      1     0     3
# 64.233.167.188       1      1     0     1
# 64.233.190.94        1      1     0     1
# 66.102.1.108         1      1     0     1
# 66.102.1.109         1      1     0     1
# 66.102.1.188         1      1     0     1
# 69.171.250.20       11      1     0    11
# 69.171.250.34        2      1     0     2
# 69.195.174.128       1      1     0     1
# 69.195.181.128       2      1     0     2
# 69.195.182.128       1      1     0     1
# 74.125.133.108       2      1     0     2
# 74.125.140.188       2      1     0     2
# 74.125.206.108       1      1     0     1
# 74.125.206.188       1      1     0     1
# 8.8.8.8             11      1     0    11
# 93.184.220.70        1      1     0     1
# 95.100.117.68        7      1     0     7
# 95.100.244.227       7      1     0     7
# 99.80.125.208        1      1     0     1
#
# [141 rows x 4 columns]

# %%
# ccreamos la lista de ip que apareccen como fuente. Aquí tb están las ips quee responden.reset_index para sacar la IP del índice.
srcip.count().reset_index()['srcip']
# Out:
# 0           10.0.28.73
# 1          10.0.29.153
# 2          10.4.45.189
# 3           10.4.45.73
# 4          10.4.46.109
# 5         104.16.65.50
# 6         104.16.66.50
# 7       104.244.42.129
# 8       104.244.42.131
# 9       104.244.42.194
# 10        104.244.42.2
# 11       104.244.42.66
# 12      108.129.35.137
# 13        13.107.42.14
# 14        13.107.42.23
# 15      13.224.117.242
# 16      13.224.119.119
# 17       13.224.119.84
# 18     151.101.130.110
# 19     151.101.134.133
# 20       151.101.134.2
# 21     151.101.134.202
# 22     151.101.134.249
# 23     151.101.194.110
# 24       151.101.2.110
# 25      151.101.66.110
# 26        157.240.0.61
# 27      157.240.221.18
# 28      157.240.221.63
# 29        162.159.24.4
#             ...
# 111      54.154.94.231
# 112      54.171.231.12
# 113      54.72.249.200
# 114         54.73.2.69
# 115       63.32.200.88
# 116       63.33.187.69
# 117     64.233.166.108
# 118     64.233.166.109
# 119     64.233.166.188
# 120     64.233.167.108
# 121     64.233.167.109
# 122     64.233.167.188
# 123      64.233.190.94
# 124       66.102.1.108
# 125       66.102.1.109
# 126       66.102.1.188
# 127      69.171.250.20
# 128      69.171.250.34
# 129     69.195.174.128
# 130     69.195.181.128
# 131     69.195.182.128
# 132     74.125.133.108
# 133     74.125.140.188
# 134     74.125.206.108
# 135     74.125.206.188
# 136            8.8.8.8
# 137      93.184.220.70
# 138      95.100.117.68
# 139     95.100.244.227
# 140      99.80.125.208
# Name: srcip, Length: 141, dtype: object

# %%
# Agrupamos con c=4 que es el tráfico bloqueado, la dirección orrigen, el nombre destino y la categoría
dstbyssrcip = df[(df['c']=='4')].groupby(['srcip','dstname', 'Category'])

# %%
dstbyssrcip.describe()
# Out:
#                                                                                stime  \
#                                                                                count
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings     6
#             bidder.criteo.com              Administrative Custom List settings    18
#             cat.nl.eu.criteo.com           Administrative Custom List settings     6
#             cm.g.doubleclick.net           Administrative Custom List settings     2
#             csm.fr.eu.criteo.net           Administrative Custom List settings     4
#             dis.criteo.com                 Administrative Custom List settings     2
#             googleads.g.doubleclick.net    Administrative Custom List settings    18
#             gum.criteo.com                 Administrative Custom List settings     8
#             pix.eu.criteo.net              Administrative Custom List settings     4
#             pubads.g.doubleclick.net       Administrative Custom List settings    15
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                             4
#             ci.phncdn.com                  Pornography                             4
#             es.pornhub.com                 Administrative Custom List settings     4
#             fonts.playboy.com              Pornography                             6
#             googleads.g.doubleclick.net    Administrative Custom List settings    17
#             media.trafficjunky.net         Administrative Custom List settings     4
#             www.googleadservices.com       Administrative Custom List settings     2
#             www.playboy.com                Pornography                            12
#             www.pornhub.com                Administrative Custom List settings     1
#
#                                                                                        \
#                                                                                unique
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings      2
#             bidder.criteo.com              Administrative Custom List settings     10
#             cat.nl.eu.criteo.com           Administrative Custom List settings      4
#             cm.g.doubleclick.net           Administrative Custom List settings      1
#             csm.fr.eu.criteo.net           Administrative Custom List settings      2
#             dis.criteo.com                 Administrative Custom List settings      1
#             googleads.g.doubleclick.net    Administrative Custom List settings     14
#             gum.criteo.com                 Administrative Custom List settings      5
#             pix.eu.criteo.net              Administrative Custom List settings      3
#             pubads.g.doubleclick.net       Administrative Custom List settings      9
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                              3
#             ci.phncdn.com                  Pornography                              3
#             es.pornhub.com                 Administrative Custom List settings      4
#             fonts.playboy.com              Pornography                              4
#             googleads.g.doubleclick.net    Administrative Custom List settings     15
#             media.trafficjunky.net         Administrative Custom List settings      4
#             www.googleadservices.com       Administrative Custom List settings      1
#             www.playboy.com                Pornography                              9
#             www.pornhub.com                Administrative Custom List settings      1
#
#                                                                                                  \
#                                                                                             top
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings  Aug 13 09:07:37
#             bidder.criteo.com              Administrative Custom List settings  Aug 13 10:32:27
#             cat.nl.eu.criteo.com           Administrative Custom List settings  Aug 13 09:07:37
#             cm.g.doubleclick.net           Administrative Custom List settings  Aug 13 09:07:51
#             csm.fr.eu.criteo.net           Administrative Custom List settings  Aug 12 11:16:16
#             dis.criteo.com                 Administrative Custom List settings  Aug 13 10:32:58
#             googleads.g.doubleclick.net    Administrative Custom List settings  Aug 12 08:08:02
#             gum.criteo.com                 Administrative Custom List settings  Aug 13 10:33:10
#             pix.eu.criteo.net              Administrative Custom List settings  Aug 13 09:07:35
#             pubads.g.doubleclick.net       Administrative Custom List settings  Aug 11 19:38:58
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                          Aug 11 18:05:54
#             ci.phncdn.com                  Pornography                          Aug 11 17:51:10
#             es.pornhub.com                 Administrative Custom List settings  Aug 11 17:51:13
#             fonts.playboy.com              Pornography                          Aug 11 17:51:00
#             googleads.g.doubleclick.net    Administrative Custom List settings  Aug 11 16:40:58
#             media.trafficjunky.net         Administrative Custom List settings  Aug 11 17:51:15
#             www.googleadservices.com       Administrative Custom List settings  Aug 12 09:47:57
#             www.playboy.com                Pornography                          Aug 11 17:49:58
#             www.pornhub.com                Administrative Custom List settings  Aug 11 17:51:10
#
#                                                                                      \
#                                                                                freq
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings    5
#             bidder.criteo.com              Administrative Custom List settings    3
#             cat.nl.eu.criteo.com           Administrative Custom List settings    3
#             cm.g.doubleclick.net           Administrative Custom List settings    2
#             csm.fr.eu.criteo.net           Administrative Custom List settings    3
#             dis.criteo.com                 Administrative Custom List settings    2
#             googleads.g.doubleclick.net    Administrative Custom List settings    2
#             gum.criteo.com                 Administrative Custom List settings    3
#             pix.eu.criteo.net              Administrative Custom List settings    2
#             pubads.g.doubleclick.net       Administrative Custom List settings    3
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                            2
#             ci.phncdn.com                  Pornography                            2
#             es.pornhub.com                 Administrative Custom List settings    1
#             fonts.playboy.com              Pornography                            2
#             googleads.g.doubleclick.net    Administrative Custom List settings    3
#             media.trafficjunky.net         Administrative Custom List settings    1
#             www.googleadservices.com       Administrative Custom List settings    2
#             www.playboy.com                Pornography                            3
#             www.pornhub.com                Administrative Custom List settings    1
#
#                                                                                   ip  \
#                                                                                count
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings     6
#             bidder.criteo.com              Administrative Custom List settings    18
#             cat.nl.eu.criteo.com           Administrative Custom List settings     6
#             cm.g.doubleclick.net           Administrative Custom List settings     2
#             csm.fr.eu.criteo.net           Administrative Custom List settings     4
#             dis.criteo.com                 Administrative Custom List settings     2
#             googleads.g.doubleclick.net    Administrative Custom List settings    18
#             gum.criteo.com                 Administrative Custom List settings     8
#             pix.eu.criteo.net              Administrative Custom List settings     4
#             pubads.g.doubleclick.net       Administrative Custom List settings    15
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                             4
#             ci.phncdn.com                  Pornography                             4
#             es.pornhub.com                 Administrative Custom List settings     4
#             fonts.playboy.com              Pornography                             6
#             googleads.g.doubleclick.net    Administrative Custom List settings    17
#             media.trafficjunky.net         Administrative Custom List settings     4
#             www.googleadservices.com       Administrative Custom List settings     2
#             www.playboy.com                Pornography                            12
#             www.pornhub.com                Administrative Custom List settings     1
#
#                                                                                        \
#                                                                                unique
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings      1
#             bidder.criteo.com              Administrative Custom List settings      1
#             cat.nl.eu.criteo.com           Administrative Custom List settings      1
#             cm.g.doubleclick.net           Administrative Custom List settings      1
#             csm.fr.eu.criteo.net           Administrative Custom List settings      1
#             dis.criteo.com                 Administrative Custom List settings      1
#             googleads.g.doubleclick.net    Administrative Custom List settings      1
#             gum.criteo.com                 Administrative Custom List settings      1
#             pix.eu.criteo.net              Administrative Custom List settings      1
#             pubads.g.doubleclick.net       Administrative Custom List settings      1
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                              1
#             ci.phncdn.com                  Pornography                              1
#             es.pornhub.com                 Administrative Custom List settings      1
#             fonts.playboy.com              Pornography                              1
#             googleads.g.doubleclick.net    Administrative Custom List settings      1
#             media.trafficjunky.net         Administrative Custom List settings      1
#             www.googleadservices.com       Administrative Custom List settings      1
#             www.playboy.com                Pornography                              1
#             www.pornhub.com                Administrative Custom List settings      1
#
#                                                                                               \
#                                                                                          top
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings  212.81.213.2
#             bidder.criteo.com              Administrative Custom List settings  212.81.213.2
#             cat.nl.eu.criteo.com           Administrative Custom List settings  212.81.213.2
#             cm.g.doubleclick.net           Administrative Custom List settings  212.81.213.2
#             csm.fr.eu.criteo.net           Administrative Custom List settings  212.81.213.2
#             dis.criteo.com                 Administrative Custom List settings  212.81.213.2
#             googleads.g.doubleclick.net    Administrative Custom List settings  212.81.213.2
#             gum.criteo.com                 Administrative Custom List settings  212.81.213.2
#             pix.eu.criteo.net              Administrative Custom List settings  212.81.213.2
#             pubads.g.doubleclick.net       Administrative Custom List settings  212.81.213.2
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                          212.81.213.2
#             ci.phncdn.com                  Pornography                          212.81.213.2
#             es.pornhub.com                 Administrative Custom List settings  212.81.213.2
#             fonts.playboy.com              Pornography                          212.81.213.2
#             googleads.g.doubleclick.net    Administrative Custom List settings  212.81.213.2
#             media.trafficjunky.net         Administrative Custom List settings  212.81.213.2
#             www.googleadservices.com       Administrative Custom List settings  212.81.213.2
#             www.playboy.com                Pornography                          212.81.213.2
#             www.pornhub.com                Administrative Custom List settings  212.81.213.2
#
#                                                                                      \
#                                                                                freq
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings    6
#             bidder.criteo.com              Administrative Custom List settings   18
#             cat.nl.eu.criteo.com           Administrative Custom List settings    6
#             cm.g.doubleclick.net           Administrative Custom List settings    2
#             csm.fr.eu.criteo.net           Administrative Custom List settings    4
#             dis.criteo.com                 Administrative Custom List settings    2
#             googleads.g.doubleclick.net    Administrative Custom List settings   18
#             gum.criteo.com                 Administrative Custom List settings    8
#             pix.eu.criteo.net              Administrative Custom List settings    4
#             pubads.g.doubleclick.net       Administrative Custom List settings   15
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                            4
#             ci.phncdn.com                  Pornography                            4
#             es.pornhub.com                 Administrative Custom List settings    4
#             fonts.playboy.com              Pornography                            6
#             googleads.g.doubleclick.net    Administrative Custom List settings   17
#             media.trafficjunky.net         Administrative Custom List settings    4
#             www.googleadservices.com       Administrative Custom List settings    2
#             www.playboy.com                Pornography                           12
#             www.pornhub.com                Administrative Custom List settings    1
#
#                                                                                   id  \
#                                                                                count
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings     6
#             bidder.criteo.com              Administrative Custom List settings    18
#             cat.nl.eu.criteo.com           Administrative Custom List settings     6
#             cm.g.doubleclick.net           Administrative Custom List settings     2
#             csm.fr.eu.criteo.net           Administrative Custom List settings     4
#             dis.criteo.com                 Administrative Custom List settings     2
#             googleads.g.doubleclick.net    Administrative Custom List settings    18
#             gum.criteo.com                 Administrative Custom List settings     8
#             pix.eu.criteo.net              Administrative Custom List settings     4
#             pubads.g.doubleclick.net       Administrative Custom List settings    15
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                             4
#             ci.phncdn.com                  Pornography                             4
#             es.pornhub.com                 Administrative Custom List settings     4
#             fonts.playboy.com              Pornography                             6
#             googleads.g.doubleclick.net    Administrative Custom List settings    17
#             media.trafficjunky.net         Administrative Custom List settings     4
#             www.googleadservices.com       Administrative Custom List settings     2
#             www.playboy.com                Pornography                            12
#             www.pornhub.com                Administrative Custom List settings     1
#
#                                                                                        \
#                                                                                unique
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings      1
#             bidder.criteo.com              Administrative Custom List settings      1
#             cat.nl.eu.criteo.com           Administrative Custom List settings      1
#             cm.g.doubleclick.net           Administrative Custom List settings      1
#             csm.fr.eu.criteo.net           Administrative Custom List settings      1
#             dis.criteo.com                 Administrative Custom List settings      1
#             googleads.g.doubleclick.net    Administrative Custom List settings      1
#             gum.criteo.com                 Administrative Custom List settings      1
#             pix.eu.criteo.net              Administrative Custom List settings      1
#             pubads.g.doubleclick.net       Administrative Custom List settings      1
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                              1
#             ci.phncdn.com                  Pornography                              1
#             es.pornhub.com                 Administrative Custom List settings      1
#             fonts.playboy.com              Pornography                              1
#             googleads.g.doubleclick.net    Administrative Custom List settings      1
#             media.trafficjunky.net         Administrative Custom List settings      1
#             www.googleadservices.com       Administrative Custom List settings      1
#             www.playboy.com                Pornography                              1
#             www.pornhub.com                Administrative Custom List settings      1
#
#                                                                                 ...  \
#                                                                                 ...
# srcip       dstname                        Category                             ...
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings  ...
#             bidder.criteo.com              Administrative Custom List settings  ...
#             cat.nl.eu.criteo.com           Administrative Custom List settings  ...
#             cm.g.doubleclick.net           Administrative Custom List settings  ...
#             csm.fr.eu.criteo.net           Administrative Custom List settings  ...
#             dis.criteo.com                 Administrative Custom List settings  ...
#             googleads.g.doubleclick.net    Administrative Custom List settings  ...
#             gum.criteo.com                 Administrative Custom List settings  ...
#             pix.eu.criteo.net              Administrative Custom List settings  ...
#             pubads.g.doubleclick.net       Administrative Custom List settings  ...
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                          ...
#             ci.phncdn.com                  Pornography                          ...
#             es.pornhub.com                 Administrative Custom List settings  ...
#             fonts.playboy.com              Pornography                          ...
#             googleads.g.doubleclick.net    Administrative Custom List settings  ...
#             media.trafficjunky.net         Administrative Custom List settings  ...
#             www.googleadservices.com       Administrative Custom List settings  ...
#             www.playboy.com                Pornography                          ...
#             www.pornhub.com                Administrative Custom List settings  ...
#
#                                                                                 op  \
#                                                                                top
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings NaN
#             bidder.criteo.com              Administrative Custom List settings NaN
#             cat.nl.eu.criteo.com           Administrative Custom List settings NaN
#             cm.g.doubleclick.net           Administrative Custom List settings NaN
#             csm.fr.eu.criteo.net           Administrative Custom List settings NaN
#             dis.criteo.com                 Administrative Custom List settings NaN
#             googleads.g.doubleclick.net    Administrative Custom List settings NaN
#             gum.criteo.com                 Administrative Custom List settings NaN
#             pix.eu.criteo.net              Administrative Custom List settings NaN
#             pubads.g.doubleclick.net       Administrative Custom List settings NaN
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                         NaN
#             ci.phncdn.com                  Pornography                         NaN
#             es.pornhub.com                 Administrative Custom List settings NaN
#             fonts.playboy.com              Pornography                         NaN
#             googleads.g.doubleclick.net    Administrative Custom List settings NaN
#             media.trafficjunky.net         Administrative Custom List settings NaN
#             www.googleadservices.com       Administrative Custom List settings NaN
#             www.playboy.com                Pornography                         NaN
#             www.pornhub.com                Administrative Custom List settings NaN
#
#                                                                                      \
#                                                                                freq
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings  NaN
#             bidder.criteo.com              Administrative Custom List settings  NaN
#             cat.nl.eu.criteo.com           Administrative Custom List settings  NaN
#             cm.g.doubleclick.net           Administrative Custom List settings  NaN
#             csm.fr.eu.criteo.net           Administrative Custom List settings  NaN
#             dis.criteo.com                 Administrative Custom List settings  NaN
#             googleads.g.doubleclick.net    Administrative Custom List settings  NaN
#             gum.criteo.com                 Administrative Custom List settings  NaN
#             pix.eu.criteo.net              Administrative Custom List settings  NaN
#             pubads.g.doubleclick.net       Administrative Custom List settings  NaN
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                          NaN
#             ci.phncdn.com                  Pornography                          NaN
#             es.pornhub.com                 Administrative Custom List settings  NaN
#             fonts.playboy.com              Pornography                          NaN
#             googleads.g.doubleclick.net    Administrative Custom List settings  NaN
#             media.trafficjunky.net         Administrative Custom List settings  NaN
#             www.googleadservices.com       Administrative Custom List settings  NaN
#             www.playboy.com                Pornography                          NaN
#             www.pornhub.com                Administrative Custom List settings  NaN
#
#                                                                                srcport  \
#                                                                                  count
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings       6
#             bidder.criteo.com              Administrative Custom List settings      18
#             cat.nl.eu.criteo.com           Administrative Custom List settings       6
#             cm.g.doubleclick.net           Administrative Custom List settings       2
#             csm.fr.eu.criteo.net           Administrative Custom List settings       4
#             dis.criteo.com                 Administrative Custom List settings       2
#             googleads.g.doubleclick.net    Administrative Custom List settings      18
#             gum.criteo.com                 Administrative Custom List settings       8
#             pix.eu.criteo.net              Administrative Custom List settings       4
#             pubads.g.doubleclick.net       Administrative Custom List settings      15
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                               4
#             ci.phncdn.com                  Pornography                               4
#             es.pornhub.com                 Administrative Custom List settings       4
#             fonts.playboy.com              Pornography                               6
#             googleads.g.doubleclick.net    Administrative Custom List settings      17
#             media.trafficjunky.net         Administrative Custom List settings       4
#             www.googleadservices.com       Administrative Custom List settings       2
#             www.playboy.com                Pornography                              12
#             www.pornhub.com                Administrative Custom List settings       1
#
#                                                                                        \
#                                                                                unique
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings      6
#             bidder.criteo.com              Administrative Custom List settings     18
#             cat.nl.eu.criteo.com           Administrative Custom List settings      6
#             cm.g.doubleclick.net           Administrative Custom List settings      2
#             csm.fr.eu.criteo.net           Administrative Custom List settings      4
#             dis.criteo.com                 Administrative Custom List settings      2
#             googleads.g.doubleclick.net    Administrative Custom List settings     18
#             gum.criteo.com                 Administrative Custom List settings      8
#             pix.eu.criteo.net              Administrative Custom List settings      4
#             pubads.g.doubleclick.net       Administrative Custom List settings     15
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                              4
#             ci.phncdn.com                  Pornography                              4
#             es.pornhub.com                 Administrative Custom List settings      4
#             fonts.playboy.com              Pornography                              6
#             googleads.g.doubleclick.net    Administrative Custom List settings     17
#             media.trafficjunky.net         Administrative Custom List settings      4
#             www.googleadservices.com       Administrative Custom List settings      2
#             www.playboy.com                Pornography                             12
#             www.pornhub.com                Administrative Custom List settings      1
#
#                                                                                        \
#                                                                                   top
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings  48254
#             bidder.criteo.com              Administrative Custom List settings  34934
#             cat.nl.eu.criteo.com           Administrative Custom List settings  36354
#             cm.g.doubleclick.net           Administrative Custom List settings  43498
#             csm.fr.eu.criteo.net           Administrative Custom List settings  44300
#             dis.criteo.com                 Administrative Custom List settings  47544
#             googleads.g.doubleclick.net    Administrative Custom List settings  54750
#             gum.criteo.com                 Administrative Custom List settings  55142
#             pix.eu.criteo.net              Administrative Custom List settings  51388
#             pubads.g.doubleclick.net       Administrative Custom List settings  55686
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                          44967
#             ci.phncdn.com                  Pornography                          43868
#             es.pornhub.com                 Administrative Custom List settings  39317
#             fonts.playboy.com              Pornography                          46427
#             googleads.g.doubleclick.net    Administrative Custom List settings  49861
#             media.trafficjunky.net         Administrative Custom List settings  38605
#             www.googleadservices.com       Administrative Custom List settings  42828
#             www.playboy.com                Pornography                          47180
#             www.pornhub.com                Administrative Custom List settings  45082
#
#                                                                                      \
#                                                                                freq
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings    1
#             bidder.criteo.com              Administrative Custom List settings    1
#             cat.nl.eu.criteo.com           Administrative Custom List settings    1
#             cm.g.doubleclick.net           Administrative Custom List settings    1
#             csm.fr.eu.criteo.net           Administrative Custom List settings    1
#             dis.criteo.com                 Administrative Custom List settings    1
#             googleads.g.doubleclick.net    Administrative Custom List settings    1
#             gum.criteo.com                 Administrative Custom List settings    1
#             pix.eu.criteo.net              Administrative Custom List settings    1
#             pubads.g.doubleclick.net       Administrative Custom List settings    1
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                            1
#             ci.phncdn.com                  Pornography                            1
#             es.pornhub.com                 Administrative Custom List settings    1
#             fonts.playboy.com              Pornography                            1
#             googleads.g.doubleclick.net    Administrative Custom List settings    1
#             media.trafficjunky.net         Administrative Custom List settings    1
#             www.googleadservices.com       Administrative Custom List settings    1
#             www.playboy.com                Pornography                            1
#             www.pornhub.com                Administrative Custom List settings    1
#
#                                                                                srcif  \
#                                                                                count
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings     6
#             bidder.criteo.com              Administrative Custom List settings    18
#             cat.nl.eu.criteo.com           Administrative Custom List settings     6
#             cm.g.doubleclick.net           Administrative Custom List settings     2
#             csm.fr.eu.criteo.net           Administrative Custom List settings     4
#             dis.criteo.com                 Administrative Custom List settings     2
#             googleads.g.doubleclick.net    Administrative Custom List settings    18
#             gum.criteo.com                 Administrative Custom List settings     8
#             pix.eu.criteo.net              Administrative Custom List settings     4
#             pubads.g.doubleclick.net       Administrative Custom List settings    15
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                             4
#             ci.phncdn.com                  Pornography                             4
#             es.pornhub.com                 Administrative Custom List settings     4
#             fonts.playboy.com              Pornography                             6
#             googleads.g.doubleclick.net    Administrative Custom List settings    17
#             media.trafficjunky.net         Administrative Custom List settings     4
#             www.googleadservices.com       Administrative Custom List settings     2
#             www.playboy.com                Pornography                            12
#             www.pornhub.com                Administrative Custom List settings     1
#
#                                                                                        \
#                                                                                unique
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings      1
#             bidder.criteo.com              Administrative Custom List settings      1
#             cat.nl.eu.criteo.com           Administrative Custom List settings      1
#             cm.g.doubleclick.net           Administrative Custom List settings      1
#             csm.fr.eu.criteo.net           Administrative Custom List settings      1
#             dis.criteo.com                 Administrative Custom List settings      1
#             googleads.g.doubleclick.net    Administrative Custom List settings      1
#             gum.criteo.com                 Administrative Custom List settings      1
#             pix.eu.criteo.net              Administrative Custom List settings      1
#             pubads.g.doubleclick.net       Administrative Custom List settings      1
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                              1
#             ci.phncdn.com                  Pornography                              1
#             es.pornhub.com                 Administrative Custom List settings      1
#             fonts.playboy.com              Pornography                              1
#             googleads.g.doubleclick.net    Administrative Custom List settings      1
#             media.trafficjunky.net         Administrative Custom List settings      1
#             www.googleadservices.com       Administrative Custom List settings      1
#             www.playboy.com                Pornography                              1
#             www.pornhub.com                Administrative Custom List settings      1
#
#                                                                                     \
#                                                                                top
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings  X2
#             bidder.criteo.com              Administrative Custom List settings  X2
#             cat.nl.eu.criteo.com           Administrative Custom List settings  X2
#             cm.g.doubleclick.net           Administrative Custom List settings  X2
#             csm.fr.eu.criteo.net           Administrative Custom List settings  X2
#             dis.criteo.com                 Administrative Custom List settings  X2
#             googleads.g.doubleclick.net    Administrative Custom List settings  X2
#             gum.criteo.com                 Administrative Custom List settings  X2
#             pix.eu.criteo.net              Administrative Custom List settings  X2
#             pubads.g.doubleclick.net       Administrative Custom List settings  X2
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                          X2
#             ci.phncdn.com                  Pornography                          X2
#             es.pornhub.com                 Administrative Custom List settings  X2
#             fonts.playboy.com              Pornography                          X2
#             googleads.g.doubleclick.net    Administrative Custom List settings  X2
#             media.trafficjunky.net         Administrative Custom List settings  X2
#             www.googleadservices.com       Administrative Custom List settings  X2
#             www.playboy.com                Pornography                          X2
#             www.pornhub.com                Administrative Custom List settings  X2
#
#
#                                                                                freq
# srcip       dstname                        Category
# 10.4.45.189 ad.doubleclick.net             Administrative Custom List settings    6
#             bidder.criteo.com              Administrative Custom List settings   18
#             cat.nl.eu.criteo.com           Administrative Custom List settings    6
#             cm.g.doubleclick.net           Administrative Custom List settings    2
#             csm.fr.eu.criteo.net           Administrative Custom List settings    4
#             dis.criteo.com                 Administrative Custom List settings    2
#             googleads.g.doubleclick.net    Administrative Custom List settings   18
#             gum.criteo.com                 Administrative Custom List settings    8
#             pix.eu.criteo.net              Administrative Custom List settings    4
#             pubads.g.doubleclick.net       Administrative Custom List settings   15
# 10.4.45.73  cdn1d-static-shared.phncdn.com Pornography                            4
#             ci.phncdn.com                  Pornography                            4
#             es.pornhub.com                 Administrative Custom List settings    4
#             fonts.playboy.com              Pornography                            6
#             googleads.g.doubleclick.net    Administrative Custom List settings   17
#             media.trafficjunky.net         Administrative Custom List settings    4
#             www.googleadservices.com       Administrative Custom List settings    2
#             www.playboy.com                Pornography                           12
#             www.pornhub.com                Administrative Custom List settings    1
#
# [19 rows x 172 columns]

# %%
# tenemos un informe hecho

# %%
internal_ip = df[(df['srcif']=='X2')]['srcip'].unique()

# %%
# direcciones ip internas
print(internal_ip)
# Out:
# ['10.4.45.73' '10.4.45.189' '172.22.193.5' '10.4.46.109' '10.0.28.73'
#  '10.0.29.153']

# %%
df.to_excel('10.4.45.xlsx',sheet_name='Sheet1')

# %%
# conversión de stime a formato de time
df['stime'] = df['stime'].apply(lambda x: datetime.strptime(df.iloc[0]['time'], '%Y-%m-%d %H:%M:%S %Z'))

# %%
# descomponemos la dst Ip para tener sus partes: IP, port e if.
df['dstip'] = df['dst'].apply(lambda x: x.split(':')[0])
df['dstport'] = df['dst'].apply(lambda x: x.split(':')[1])
df['dstif'] = df['dst'].apply(lambda x: x.split(':')[2])

# %%
# https://stackoverflow.com/questions/22345951/python-idiom-for-creating-dict-of-dict-of-list
conver = {}

for i in range(0,len(df)):
    # solo para las ips internas vamos a generar un array de conversaciones
    srcport = df.iloc[i]['srcport']
    dstip   = df.iloc[i]['dstip']
    dstport = df.iloc[i]['dstport']
    srcip   = df.iloc[i]['srcip']    
    appcat  = df.iloc[i]['appcat']
    proto   = df.iloc[i]['proto']
    sent    = df.iloc[i]['sent']
    rcvd    = df.iloc[i]['rcvd']
    cdur    = df.iloc[i]['cdur']
    app     = df.iloc[i]['app']
    n       = df.iloc[i]['n']
    sid     = df.iloc[i]['sid']
    appid   = df.iloc[i]['appid']
    catid   = df.iloc[i]['catid']
    dstname = df.iloc[i]['dstname']
    time    = df.iloc[i]['time']
    
    if srcip in internal_ip:
        # print(str(i)+'  '+srcip)
        if not srcip in conver.keys():
            #print(srcip)
            conver[srcip] = {}
        if not dstip+':'+dstport+':'+srcport in conver[srcip].keys():
            #print(dstip+':'+dstport+':'+srcport)
            conver[srcip][dstip+':'+dstport+':'+srcport] = [[i],[time, appcat, proto, sent, rcvd, cdur, app, n, sid, appid, catid, dstname]] 
        else:
            conver[srcip][dstip+':'+dstport+':'+srcport][0].append([i])
            conver[srcip][dstip+':'+dstport+':'+srcport][1].append([time, appcat, proto, sent, rcvd, cdur, app, n, sid, appid, catid, dstname]) 

    if dstip in internal_ip:
        if not dstip in conver.keys():
            #print(srcip)
            conver[dstip] = {}
        if not srcip+':'+srcport+':'+dstport in conver[dstip].keys():
            #print(dstip+':'+dstport+':'+srcport)
            conver[dstip][srcip+':'+srcport+':'+dstport] = [[i],[time, appcat, proto, sent, rcvd, cdur, app, n, sid, appid, catid, dstname]] 
        else:
            conver[dstip][srcip+':'+srcport+':'+dstport][0].append([i])
            conver[dstip][srcip+':'+srcport+':'+dstport][1].append([time, appcat, proto, sent, rcvd, cdur, app, n, sid, appid, catid, dstname])
